# %%
# https://www.psycopg.org/docs/usage.html 
# https://www.psycopg.org/docs/module.html#psycopg2.connect

# %%
# FIRST: 
# Run the SQL statements needed to GRANT access
# TO 'testuser' on the dvdrental DB

# %%
import psycopg2
# Out:
# Running cells with '.venv (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/R/UCD_FullStack/04DB/__demo/db_postgres/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
#Test a connection
import psycopg2
# # NEVER PUT a password in the code:/connection-string  used below: just for simple test/learning
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test1")

print(conn)
conn.close() # don't forget to close
print(conn)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Test a connection
# ----> 2 import psycopg2
#       3 # # NEVER PUT a password in the code:/connection-string  used below: just for simple test/learning
#       4 conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test1")
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
#Test a connection 
# passing a connection-string to psycopg2
import psycopg2
connection_string = "dbname=dvdrental user=testuser password=test123"
conn = psycopg2.connect(connection_string)

print(conn)
conn.close() # don't forget to close
print(conn)

# %%
## ATTEMPT CONNECT TO dbname="postgres"
## SEE fails IF USER doesn't have priviliges
## Currently testuser only has priviliges for db: `dvdrental`
import psycopg2
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test123")

try:
    curr = conn.cursor()
    curr.execute("SELECT * FROM staff;")
finally:
    conn.close() # don't forget to close

# %%
## Test execute a
##  SELECT * FROM staff;
import psycopg2
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test123")

curr = conn.cursor()
curr.execute("SELECT * FROM staff;")
result = curr.fetchall()
for record in result:
    print(record)

curr.close()
conn.close() # don't forget to close

# %%
## Putting the SQL into a String
import psycopg2
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test123")

SQL = "SELECT * FROM staff;"
print(SQL)  # print SQL string

curr = conn.cursor()
curr.execute(SQL)               #pass a String to execute()
result = curr.fetchall()        #try: .fetchone()

for record in result:
    print(record)
    
curr.close()
conn.close() # don't forget to close

# %%
## Building an SQL String with user input
## using (e.g.) -> input() 
import psycopg2
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test123")

SQL = f"SELECT * FROM {input('Enter table name: ')};"
print(SQL)  # print SQL string

curr = conn.cursor()
curr.execute(SQL)
result = curr.fetchall()
for record in result:
    print(record)
    
    
curr.close()
conn.close() # don't forget to close

# %%
## DANGER!! SQL INJECTION... CARE NEEDED
## Typically NEVER build an SQL String like this...
import psycopg2
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test123")

# SQL = f"SELECT * FROM Staff WHERE first_name = '{input('Enter first_name: ')}';"

# DANGER ABOVE: SQL INJECTION: consider...
SQL = f"SELECT * FROM Staff WHERE first_name = 'Mike' OR TRUE;"

print(SQL)  # print SQL string
curr = conn.cursor()
curr.execute(SQL)
result = curr.fetchall()
print(result)
    
curr.close()
conn.close() # don't forget to close

# %%
## USE SQL parameters to prevent SQL INJECTION
## To prevent SQL injection attacks: parameterized queries
import psycopg2
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test123")

# Get user input
first_name = input("Enter first_name: ")

# Build the SQL query string with a placeholder %s for the parameter
SQL = "SELECT * FROM Staff WHERE first_name = %s"
data = (first_name, ) # pass parameter as a py single-element tuple

curr = conn.cursor()
curr.execute(SQL, data ) 

result = curr.fetchall()  #experiment: fetchone()
for record in result:
    print(record)
    
curr.close()
conn.close() # don't forget to close

## ABOVE
## curr.execute( SQL, data )
## data needs to be a Python sequence
## A Tuple is a sequence but to make a single-element tuple
## need: ( val, ) ...i.e. trailing comma

# %%
## At this point: revert to psql (for example)
## and Grant update priviliges on the Staff table for the testuser
## THEN follow below...

# %%
## The COMMIT concept
## Attempting an UPDATE after 
## GRANTing UPDATE priviliges...

import psycopg2
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test123")

SQL_UPDATE = "UPDATE staff SET first_name = 'Michael' where first_name = 'Mike';"
print(SQL_UPDATE)  # print SQL string
curr = conn.cursor()
curr.execute(SQL_UPDATE)

#THEN
SQL_SELECT = "SELECT * FROM staff;"
print(SQL_SELECT)  # print SQL string

curr.execute(SQL_SELECT)
result = curr.fetchall()  
for record in result:
    print(record)
    
curr.close()
conn.close() # don't forget to close

# %%
## but now try 
## psql:
## SELECT * FROM staff;

# %%
## See a new connection 
## through python
## No change to the DB
import psycopg2
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test123")

SQL_SELECT = "SELECT * FROM staff;"
print(SQL_SELECT)  # print SQL string

curr = conn.cursor()
curr.execute(SQL_SELECT)
result = curr.fetchall()  #experiment: fetchone()
for record in result:
    print(record)
    
curr.close()
conn.close() # don't forget to close

# %%
## REPEATING ABOVE NOW
## ONLY with conn.commit();

# %%
import psycopg2
conn = psycopg2.connect(dbname="dvdrental", user="testuser", password="test123")

SQL_UPDATE = "UPDATE staff SET first_name = 'Michael' where first_name = 'Mike';"
print(SQL_UPDATE)  # print SQL string
curr = conn.cursor()
curr.execute(SQL_UPDATE)
conn.commit()               ##ADDED conn.commit()


#THEN
SQL_SELECT = "SELECT * FROM staff;"
print(SQL_SELECT)  # print SQL string

curr.execute(SQL_SELECT)
result = curr.fetchall()  #experiment: fetchone()
for record in result:
    print(record)
    
curr.close()
conn.close() # don't forget to close

# %%
## SEE
## psql:
## SELECT * FROM staff;
## DB CHANGED after 'conn.commit()'

# %%
import os
print(f"current: {os.getcwd()}")
os.chdir('..')

with open('testfile.txt', 'w') as testfile:
    for file_or_folder in os.listdir():
        print(file_or_folder)
    #auto-close file

print("program continues...")

# %%
## Auto-COMMIT
## using the python 'with' syntax
## psycopg2: Connection string
## and 
## WITH SYNTAX TO AUTO COMMIT?
## https://www.psycopg.org/docs/usage.html#with-statement

## RUN a SELECT * first to see first_name currently 'Micael'
import psycopg2
connection_string = "dbname=dvdrental user=testuser password=test123"

SQL_UPDATE = "UPDATE staff SET first_name = 'Mike' where first_name = 'Michael';" 
print(SQL_UPDATE)  # print SQL string

with psycopg2.connect(connection_string) as conn:
    curr = conn.cursor()
    curr.execute(SQL_UPDATE)  
    #auto-commit(): conn.commit() behind the scenes

curr.close()
conn.close()

# %%
# https://www.psycopg.org/docs/usage.html#with-statement
import psycopg2
connection_string = "dbname=dvdrental user=testuser password=test123"
conn = psycopg2.connect(connection_string)

with conn:  #will auto-commit the conn
    with conn.cursor() as curr: #will auto-close the cursor
        curr.execute("SELECT * FROM staff")
        

        for record in curr.fetchall():
            print(record)
        #curr.close() #auto
    #conn.commit() #auto

conn.close()
