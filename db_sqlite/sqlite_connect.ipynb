# %%
from sqlalchemy import create_engine, text

connection_string = "sqlite:///first.db"
engine = create_engine(connection_string, echo=True)

with engine.connect() as conn:
    result = conn.execute( text("SELECT * FROM facility") )
    rows = result.all()

print(rows)
# Out:
# 2026-02-26 20:11:47,676 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-26 20:11:47,679 INFO sqlalchemy.engine.Engine SELECT * FROM facility
# 2026-02-26 20:11:47,682 INFO sqlalchemy.engine.Engine [generated in 0.00667s] ()
# 2026-02-26 20:11:47,688 INFO sqlalchemy.engine.Engine ROLLBACK
# [(0, 'Tennis Court 1'), (1, 'Tennis Court 2'), (2, 'Tennis Court3')]
